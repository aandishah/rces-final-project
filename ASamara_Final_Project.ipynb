# %% [markdown]
# # Final Project

# %%
import pandas as pd
import xarray as xr 
import numpy as np

# %%
# Load SST data
url = 'http://www.esrl.noaa.gov/psd/thredds/dodsC/Datasets/noaa.ersst.v5/sst.mnmean.nc'
sst = xr.open_dataset(url, drop_variables=['time_bnds'])

# %%
# Load Monthly Surface Temperature (SST for ENSO) 
ds_url = 
ds = xr.open_dataset('http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods', 
                     decode_times=False)
temp = ds.temp[-1].values - 273.15
lon = ds.X.values
lat = ds.Y.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 # Load Monthly Surface Temperature (SST for ENSO)
#       2 ds_url = 'http://iridl.ldeo.columbia.edu/SOURCES/.NOAA/.NCEP-NCAR/.CDAS-1/.MONTHLY/.Diagnostic/.surface/.temp/dods'
# ----> 3 ds = xr.open_dataset(ds_url, decode_times=False)
#       5 temp = ds.temp[-1].values - 273.15
#       6 lon = ds.X.values
#
# NameError: name 'xr' is not defined

# %%
single_reanalysis = xarray.open_zarr(
    "gs://gcp-public-data-arco-era5/co/single-level-reanalysis.zarr",
    chunks={'time': 48},
    consolidated=True,
)
single_reanalysis
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 374016, values: 542080)
# Coordinates:
#     depthBelowLandLayer  float64 ...
#     entireAtmosphere     float64 ...
#     latitude             (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#     longitude            (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#     number               int64 ...
#     step                 timedelta64[ns] ...
#     surface              float64 ...
#   * time                 (time) datetime64[ns] 1979-01-01 ... 2021-08-31T23:0...
#     valid_time           (time) datetime64[ns] dask.array<chunksize=(48,), meta=np.ndarray>
# Dimensions without coordinates: values
# Data variables: (12/38)
#     cape                 (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     d2m                  (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
# ...

# %%
# Weight the Dataset
