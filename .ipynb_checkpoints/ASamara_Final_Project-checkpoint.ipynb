# %% [markdown]
# # Understanding drivers and responses of Sea Surface Temperature and Soil Moisture brtween 2011 and 2020 using reanalysis data
# ## Final Project: Research Computing for the Earth Sciences
#
# #### Aandishah Tehzeeb Samara, aandishah.s@columbia.edu
# #### Columbia University, Fall 2022

# %% [markdown]
# ## Project Goals
#
# Over the last few decades, the observed frequency of heavy precipitation, flooding and droughts has increased considerably. These events cause detrimental impacts on human societies and ecosystems. Climate-model simulations predict that due to anthropogenic forcing, these impacts are likely to become even more intensified. The past years of La Nina have shown to amplify this global phenomenon, leading to more drastic floodings and droughts across the world. This study aims to understand the spatial correlations between the current and past La Nina and El Nino events and its impact on land. Understanding how, where and when these events and their results are occurring would help inform people and plan accordingly as climate change escalates the and scale and frequency of these events.

# %% [markdown]
# # Research Questions:
# ##### 1. How similar or different are patterns for sea surface temperature and soil moisture?
# ##### 2. How are the sea surface temperature and soil moisture anomalies [2015 - 2020] spatially correlated? Are they different spatially and quantitatively over land and over the ocean?
# ##### 3. How well are these anomalies interpreted in ENSO teleconnections?

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import xarray as xr 
import numpy as np 
import scipy.spatial
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from scipy.stats import pearsonr

# %% [markdown]
# ## Importing Reanalysis Data
#
# #### Sea Surface Temperature:
# ##### Temperature of sea water near the surface. This is a combination of satellites measure sea surface temperature and observational data.
#
# #### Soil Moisture:
# ##### Volume of water in soil layer 1 (0 - 7cm, the surface is at 0cm).

# %%
#Load ERA-5 Data
reanalysis = xr.open_zarr(
    'gs://gcp-public-data-arco-era5/co/single-level-reanalysis.zarr', 
    chunks={'time': 48},
    consolidated=True,
    drop_variables=['entireAtmosphere', 
                   'depthBelowLandLayer', 
                   'number',
                   'step',
                   'valid_time', 
                   'surface'])

# %%
reanalysis
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 374016, values: 542080)
# Coordinates:
#     latitude   (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#     longitude  (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#   * time       (time) datetime64[ns] 1979-01-01 ... 2021-08-31T23:00:00
# Dimensions without coordinates: values
# Data variables: (12/38)
#     cape       (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     d2m        (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     hcc        (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     istl1      (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     istl2      (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     istl3      (time, values) float32 dask.array<chunksize=(48, 542080), meta=np.ndarray>
#     ...         ...
# ...

# %% [markdown]
# ## Manipulating the data
#
# ### For my research project, I was interested in comparing how these variables changed on a seasonal scale. Hence they were aggregated on a 3 month average to remove the chaotic natural atmospheric variability.

# %%
# Resample to seasonal mean
seasonal = reanalysis.sel(time=slice('2014-12-01', '2020-12-01')).resample(time="QS-DEC").mean()
seasonal
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 25, values: 542080)
# Coordinates:
#     longitude  (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#     latitude   (values) float64 dask.array<chunksize=(542080,), meta=np.ndarray>
#   * time       (time) datetime64[ns] 2014-12-01 2015-03-01 ... 2020-12-01
# Dimensions without coordinates: values
# Data variables: (12/38)
#     cape       (time, values) float32 dask.array<chunksize=(1, 542080), meta=np.ndarray>
#     d2m        (time, values) float32 dask.array<chunksize=(1, 542080), meta=np.ndarray>
#     hcc        (time, values) float32 dask.array<chunksize=(1, 542080), meta=np.ndarray>
#     istl1      (time, values) float32 dask.array<chunksize=(1, 542080), meta=np.ndarray>
#     istl2      (time, values) float32 dask.array<chunksize=(1, 542080), meta=np.ndarray>
#     istl3      (time, values) float32 dask.array<chunksize=(1, 542080), meta=np.ndarray>
#     ...         ...
# ...

# %%
# Create a for loop for listing each variable's long name
for i in list(reanalysis.keys()):    
    print(i.ljust(20), ":", reanalysis[i].attrs['long_name'])
# Out:
# cape                 : Convective available potential energy
# d2m                  : 2 metre dewpoint temperature
# hcc                  : High cloud cover
# istl1                : Ice temperature layer 1
# istl2                : Ice temperature layer 2
# istl3                : Ice temperature layer 3
# istl4                : Ice temperature layer 4
# lcc                  : Low cloud cover
# mcc                  : Medium cloud cover
# msl                  : Mean sea level pressure
# p79.162              : Vertical integral of divergence of cloud liquid water flux
# p80.162              : Vertical integral of divergence of cloud frozen water flux
# siconc               : Sea ice area fraction
# skt                  : Skin temperature
# sp                   : Surface pressure
# sst                  : Sea surface temperature
# stl1                 : Soil temperature level 1
# stl2                 : Soil temperature level 2
# stl3                 : Soil temperature level 3
# ...

# %% [markdown]
# # Regridding the Data
#
# #### The original data came in a Gaussian Grid format. This needed to be converted to a lat/lon so that it would be plotted and sliced in that dimension.

# %% [markdown]
# # Regridding
# <p> Reference: https://confluence.ecmwf.int/display/FCST/Gaussian+grids <p>
#
# ![image.png](attachment:36a3c878-2061-40a6-9447-b3165a9c519b.png)

# %%
def mirror_point_at_360(ds):
  extra_point = (
      ds.where(ds.longitude == 0, drop=True)
      .assign_coords(longitude=lambda x: x.longitude + 360)
  )
  return xr.concat([ds, extra_point], dim='values')

def build_triangulation(x, y):
  grid = np.stack([x, y], axis=1)
  return scipy.spatial.Delaunay(grid)

def interpolate(data, tri, mesh):
  indices = tri.find_simplex(mesh)
  ndim = tri.transform.shape[-1]
  T_inv = tri.transform[indices, :ndim, :]
  r = tri.transform[indices, ndim, :]
  c = np.einsum('...ij,...j', T_inv, mesh - r)
  c = np.concatenate([c, 1 - c.sum(axis=-1, keepdims=True)], axis=-1)
  result = np.einsum('...i,...i', data[:, tri.simplices[indices]], c)
  return np.where(indices == -1, np.nan, result)

# %%
#Select Date Range 1979 - 2020
rs_1520 = seasonal.pipe(mirror_point_at_360)
tri = build_triangulation(rs_1520.longitude, rs_1520.latitude)

# %%
longitude = np.linspace(0, 360, num=360*4+1)
latitude = np.linspace(-90, 90, num=180*4+1)
mesh = np.stack(np.meshgrid(longitude, latitude, indexing='ij'), axis=-1)

# %%
#Regridding Surface Sea Temperature 
sst_mesh = interpolate(rs_1520.sst.values, tri, mesh)
sst_1520 = xr.DataArray(sst_mesh, coords=[('time', rs_1520.time.data), ('longitude', longitude), ('latitude', latitude)])
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/flox/aggregate_flox.py:105: RuntimeWarning: invalid value encountered in divide
#   out /= nanlen(group_idx, array, size=size, axis=axis, fill_value=0)
# /srv/conda/envs/notebook/lib/python3.9/site-packages/flox/aggregations.py:258: RuntimeWarning: invalid value encountered in divide
#   finalize=lambda sum_, count: sum_ / count,

# %%
sst_1520
# Out:
# <xarray.DataArray (time: 25, longitude: 1441, latitude: 721)>
# array([[[         nan,          nan,          nan, ..., 271.46024306,
#          271.46024306,          nan],
#         [         nan,          nan,          nan, ..., 271.46024306,
#          271.46024306,          nan],
#         [         nan,          nan,          nan, ..., 271.46024306,
#          271.46024306,          nan],
#         ...,
#         [         nan,          nan,          nan, ..., 271.46024306,
#          271.46024306,          nan],
#         [         nan,          nan,          nan, ..., 271.46024306,
#          271.46024306,          nan],
#         [         nan,          nan,          nan, ..., 271.46024306,
#          271.46024306,          nan]],
#
#        [[         nan,          nan,          nan, ..., 271.46025815,
#          271.46025815,          nan],
#         [         nan,          nan,          nan, ..., 271.46025815,
#          271.46025815,          nan],
# ...

# %%
# Regridding Soil Moisture
sm_mesh = interpolate(rs_1520.swvl1.values, tri, mesh)
sm_1520 = xr.DataArray(sm_mesh, coords=[('time', rs_1520.time.data), ('longitude', longitude), ('latitude', latitude)])

# %%
sm_1520
# Out:
# <xarray.DataArray (time: 25, longitude: 1441, latitude: 721)>
# array([[[            nan,  1.83036184e-01,  1.85494698e-01, ...,
#           7.36624416e-08,  7.36624416e-08,             nan],
#         [            nan,  1.82232902e-01,  1.85709480e-01, ...,
#           7.36624416e-08,  7.36624416e-08,             nan],
#         [            nan,  1.83718407e-01,  1.86211452e-01, ...,
#           7.36624416e-08,  7.36624416e-08,             nan],
#         ...,
#         [            nan,  1.82654829e-01,  1.83111570e-01, ...,
#           7.36624416e-08,  7.36624416e-08,             nan],
#         [            nan,  1.82599932e-01,  1.84159539e-01, ...,
#           7.36624416e-08,  7.36624416e-08,             nan],
#         [            nan,  1.83036184e-01,  1.85494698e-01, ...,
#           7.36624416e-08,  7.36624416e-08,             nan]],
#
#        [[            nan,  1.55483401e-01,  1.84220580e-01, ...,
#          -1.01679504e-07, -1.01679504e-07,             nan],
# ...

# %%
#Meaning across time 
lat = sst_1520.latitude
lon = sst_1520.longitude
sst_time_mean = sst_1520.mean(dim=('time'), keep_attrs = True)
sm_time_mean = (sm_1520.mean(dim=('time'), keep_attrs = True)) 
sst = (sst_time_mean.values.T) - 273.15
sm = (sm_time_mean.values.T) 
lat.shape, lon.shape, sst.shape, sm.shape
# Out:
# ((721,), (1441,), (721, 1441), (721, 1441))

# %%
#Apply Land Mask to SM Data 
mask = xr.open_dataset('lsm_1279l4_0.1x0.1.grb_v4_unpack.nc')
masked = mask.lsm 
mask_interp = mask.interp_like(sm_1520[0], method='nearest')
land_mask = mask_interp.lsm[0]

# %% [markdown]
# # 1. How similar or different are patterns for sea surface temperature and soil moisture?
#
# By plotting contour plots, we can see if there are zonal patterns and variations that correspond between the sea surface and soil moisture data. Immediately looking at the data,we find that there is a clear zonal coorelation between the sea surface temperature and the soil moisture.

# %%
# Plot the time mean 
fig, ax = plt.subplots(figsize = [20, 18], nrows= 2)
fig.tight_layout()
#Figure 1 
levels = np.arange(-10, 45, 5)
sst_map = ax[0].contourf(lon, lat, sst, levels, cmap = "coolwarm", extend = "both")
#ax[0].contour(lon, lat, temp, levels=[0], colors = 'white', extend = "both")
ax[0].set_xticks([])
#ax[0].set_xlabel('Longitude')
ax[0].set_ylabel('Latitude')
color_bar_ratio = sst.shape[0]/sst.shape[1] 
ax[0].set_title("Sea Surface Temperature Mean From 2015 to 2020", fontsize = 20)
plt.colorbar(sst_map , ax =ax[0], label ='\N{DEGREE SIGN}C', shrink = 0.7)

levels2 = np.arange(0.0, 0.5, 0.01)
sm_map = ax[1].contourf(lon, lat, sm, levels2, cmap = "Blues", extend = "both")
#ax[1].contour(lon, lat, sm, levels=[0.0], colors = 'white', extend = "both")
ax[1].set_xticks([0, 60, 120, 180, 240, 300])
ax[1].set_xlabel('Longitude')
ax[1].set_ylabel('Latitude')
color_bar_ratio2 = sm.shape[0]/sm.shape[1] 
ax[1].set_title("Soil Moisture Mean From 2015 to 2020", fontsize = 20)
plt.colorbar(sm_map, ax =ax[1], label ='m$^3$', shrink = 0.7)
plt.show()

# %%
#Group by seasons
sst_s = sst_1520.groupby('time.month')
sm_s = sm_1520.groupby('time.month')

# %%
# Calculate Seasonal Time Mean
sst_sm = sst_s.mean(dim = 'time')
sm_sm = sm_s.mean(dim = 'time')
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/flox/aggregate_flox.py:105: RuntimeWarning: invalid value encountered in divide
#   out /= nanlen(group_idx, array, size=size, axis=axis, fill_value=0)

# %%
#Zonal Mean 
sst_zonal = sst_sm.mean(dim='longitude').transpose()
sm_zonal = sm_sm.mean(dim='longitude').transpose()

# %%
fig, ax = plt.subplots(figsize=(10, 8), ncols=2)
ax[0].contourf(sst_zonal.month, sst_zonal.latitude, sst_zonal.values, cmap = "coolwarm")
ax[1].contourf(sm_zonal.month, sm_zonal.latitude, sm_zonal.values, cmap = "Blues")
ax[0].set_ylabel('Latitude')
ax[1].set_ylabel('Latitude')
ax[0].set_xlabel('Month')
ax[1].set_xlabel('Month')
ax[0].set_title("Zonal Mean of Sea Surface Temperature")
ax[1].set_title("Zonal Mean of Soil Moisture")
plt.colorbar(sst_map , ax =ax[0], label ='\N{DEGREE SIGN}C', shrink = 0.7)
plt.colorbar(sm_map, ax =ax[1], label ='m$^3$', shrink = 0.7)
plt.show()

# %% [markdown]
# ### 2.	How are the sea surface temperature and soil moisture anomalies [2015 - 2020] spatially correlated? How are they different spatially and quantitatively over land and over the ocean?

# %%
# Calculate Anomaly for Sea Surface Temperature and Soil Moisture
sst_anom = (sst_1520 - sst_1520.mean(dim='time'))
sm_anom = (sm_1520 - sm_1520.mean(dim='time'))

# %%
(    sst_anom.T.groupby("time.month")
    .reduce(np.mean)
    .plot(col="month", col_wrap=4)
    .fig.suptitle("Sea Surface Anomaly Across Seasons")
)
plt.show()

# %%
( sm_anom.T.groupby("time.month")
    .reduce(np.mean)
    .plot(col="month", col_wrap=4)
    .fig.suptitle("Soil Moisture Anomaly Across Seasons")
)
plt.show()

# %%
# Group the data for monthly values
sst_monthly = sst_anom.groupby("time.month")
sm_monthly = sm_anom.groupby("time.month")

# %%
n = len(sst_monthly[3][0].values.flatten()) #length of one flattened array
sst_flat = np.empty((n, 6, 4)) # (x, y z) (values, time, season)
sm_flat = np.empty((n, 6, 4)) # Same shape of data

# %%
season = [3, 6, 9, 12]
# Flatten Sea Surface Temperature
for i in range(4):
    for j in range(6):
        sst_flat[:, j, i] = sst_monthly[season[i]][j].values.flatten()
# Flatten Sea Surface Temperature
for i in range(4):
    for j in range(6):
        sm_flat[:, j, i] = sm_monthly[season[i]][j].values.flatten()

# %%
#Check that the values propagated correctly
sm_monthly[season[0]][0]
sm_flat[:, 0, 0]
# Out:
# array([            nan, -3.68422179e-02, -2.08280873e-02, ...,
#        -7.80369452e-08, -7.80369452e-08,             nan])

# %%
years = (np.linspace(2015, 2020, 6)).astype(np.int64)
years
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020])

# %%
# For Sea Surface Seasonal 
spr_sst = pd.DataFrame(sst_flat[:, :, 0], columns = [years]).dropna()
sum_sst = pd.DataFrame(sst_flat[:, :, 1], columns = [years]).dropna()
fall_sst = pd.DataFrame(sst_flat[:, :, 2], columns = [years]).dropna()
win_sst = pd.DataFrame(sst_flat[:, :, 3], columns = [years]).dropna()

# %% [markdown]
# # Correlation

# %%
def color_positive_green(val):
    if val >= 0.5:
        color = 'green'
    else:
        color = 'black'
    return 'color: %s' % color

# %%
print("Spring Sea Surface Correlation = ")
spr_sst_corr = spr_sst.corr()
spr_sst_corr.style.applymap(color_positive_green)
# Out:
# Spring Sea Surface Correlation =
# <style type="text/css">
# #T_afccb_row0_col0, #T_afccb_row0_col1, #T_afccb_row0_col2, #T_afccb_row0_col3, #T_afccb_row0_col4, #T_afccb_row0_col5, #T_afccb_row1_col0, #T_afccb_row1_col1, #T_afccb_row1_col2, #T_afccb_row1_col3, #T_afccb_row1_col4, #T_afccb_row1_col5, #T_afccb_row2_col0, #T_afccb_row2_col1, #T_afccb_row2_col2, #T_afccb_row2_col3, #T_afccb_row2_col4, #T_afccb_row2_col5, #T_afccb_row3_col0, #T_afccb_row3_col1, #T_afccb_row3_col2, #T_afccb_row3_col3, #T_afccb_row3_col4, #T_afccb_row3_col5, #T_afccb_row4_col0, #T_afccb_row4_col1, #T_afccb_row4_col2, #T_afccb_row4_col3, #T_afccb_row4_col4, #T_afccb_row4_col5, #T_afccb_row5_col0, #T_afccb_row5_col1, #T_afccb_row5_col2, #T_afccb_row5_col3, #T_afccb_row5_col4, #T_afccb_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_afccb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afccb_level0_col0" class="col_heading level0 col0" >(2015,)</th>
# ...

# %%
print("Summer Sea Surface Seasonal Correlation = ")
sum_sst_corr = sum_sst.corr()
sum_sst_corr.style.applymap(color_positive_green)
# Out:
# Summer Sea Surface Seasonal Correlation =
# <style type="text/css">
# #T_98ddf_row0_col0, #T_98ddf_row0_col1, #T_98ddf_row0_col2, #T_98ddf_row0_col3, #T_98ddf_row0_col4, #T_98ddf_row0_col5, #T_98ddf_row1_col0, #T_98ddf_row1_col1, #T_98ddf_row1_col2, #T_98ddf_row1_col3, #T_98ddf_row1_col4, #T_98ddf_row1_col5, #T_98ddf_row2_col0, #T_98ddf_row2_col1, #T_98ddf_row2_col2, #T_98ddf_row2_col3, #T_98ddf_row2_col4, #T_98ddf_row2_col5, #T_98ddf_row3_col0, #T_98ddf_row3_col1, #T_98ddf_row3_col2, #T_98ddf_row3_col3, #T_98ddf_row3_col4, #T_98ddf_row3_col5, #T_98ddf_row4_col0, #T_98ddf_row4_col1, #T_98ddf_row4_col2, #T_98ddf_row4_col3, #T_98ddf_row4_col4, #T_98ddf_row4_col5, #T_98ddf_row5_col0, #T_98ddf_row5_col1, #T_98ddf_row5_col2, #T_98ddf_row5_col3, #T_98ddf_row5_col4, #T_98ddf_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_98ddf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
print("Fall Sea Surface Seasonal Correlation = ")
fall_sst_corr = fall_sst.corr()
fall_sst_corr.style.applymap(color_positive_green)
# Out:
# Fall Sea Surface Seasonal Correlation =
# <style type="text/css">
# #T_0fabc_row0_col0, #T_0fabc_row0_col1, #T_0fabc_row0_col2, #T_0fabc_row0_col3, #T_0fabc_row0_col4, #T_0fabc_row0_col5, #T_0fabc_row1_col0, #T_0fabc_row1_col1, #T_0fabc_row1_col2, #T_0fabc_row1_col3, #T_0fabc_row1_col4, #T_0fabc_row1_col5, #T_0fabc_row2_col0, #T_0fabc_row2_col1, #T_0fabc_row2_col2, #T_0fabc_row2_col3, #T_0fabc_row2_col4, #T_0fabc_row2_col5, #T_0fabc_row3_col0, #T_0fabc_row3_col1, #T_0fabc_row3_col2, #T_0fabc_row3_col3, #T_0fabc_row3_col4, #T_0fabc_row3_col5, #T_0fabc_row4_col0, #T_0fabc_row4_col1, #T_0fabc_row4_col2, #T_0fabc_row4_col3, #T_0fabc_row4_col4, #T_0fabc_row4_col5, #T_0fabc_row5_col0, #T_0fabc_row5_col1, #T_0fabc_row5_col2, #T_0fabc_row5_col3, #T_0fabc_row5_col4, #T_0fabc_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_0fabc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0fabc_level0_col0" class="col_heading level0 col0" >(2015,)</th>
# ...

# %%
print("Winter Sea Surface Seasonal Correlation = ")
win_sst_corr = fall_sst.corr()
win_sst_corr.style.applymap(color_positive_green)
# Out:
# Winter Sea Surface Seasonal Correlation =
# <style type="text/css">
# #T_e9c46_row0_col0, #T_e9c46_row0_col1, #T_e9c46_row0_col2, #T_e9c46_row0_col3, #T_e9c46_row0_col4, #T_e9c46_row0_col5, #T_e9c46_row1_col0, #T_e9c46_row1_col1, #T_e9c46_row1_col2, #T_e9c46_row1_col3, #T_e9c46_row1_col4, #T_e9c46_row1_col5, #T_e9c46_row2_col0, #T_e9c46_row2_col1, #T_e9c46_row2_col2, #T_e9c46_row2_col3, #T_e9c46_row2_col4, #T_e9c46_row2_col5, #T_e9c46_row3_col0, #T_e9c46_row3_col1, #T_e9c46_row3_col2, #T_e9c46_row3_col3, #T_e9c46_row3_col4, #T_e9c46_row3_col5, #T_e9c46_row4_col0, #T_e9c46_row4_col1, #T_e9c46_row4_col2, #T_e9c46_row4_col3, #T_e9c46_row4_col4, #T_e9c46_row4_col5, #T_e9c46_row5_col0, #T_e9c46_row5_col1, #T_e9c46_row5_col2, #T_e9c46_row5_col3, #T_e9c46_row5_col4, #T_e9c46_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_e9c46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
# For Soil Moisture Seasonal 
spr_sm = pd.DataFrame(sm_flat[:, :, 0], columns = [years]).dropna()
sum_sm = pd.DataFrame(sm_flat[:, :, 1], columns = [years]).dropna()
fall_sm = pd.DataFrame(sm_flat[:, :, 2], columns = [years]).dropna()
win_sm = pd.DataFrame(sm_flat[:, :, 3], columns = [years]).dropna()

# %%
print("Spring Soil Moisture Correlation = ")
spr_sm_corr = spr_sm.corr()
spr_sm_corr.style.applymap(color_positive_green)
# Out:
# Spring Soil Moisture Correlation =
# <style type="text/css">
# #T_94f3d_row0_col0, #T_94f3d_row0_col1, #T_94f3d_row0_col2, #T_94f3d_row1_col0, #T_94f3d_row1_col1, #T_94f3d_row1_col2, #T_94f3d_row1_col3, #T_94f3d_row2_col0, #T_94f3d_row2_col1, #T_94f3d_row2_col2, #T_94f3d_row2_col3, #T_94f3d_row2_col4, #T_94f3d_row3_col1, #T_94f3d_row3_col2, #T_94f3d_row3_col3, #T_94f3d_row3_col4, #T_94f3d_row3_col5, #T_94f3d_row4_col2, #T_94f3d_row4_col3, #T_94f3d_row4_col4, #T_94f3d_row4_col5, #T_94f3d_row5_col3, #T_94f3d_row5_col4, #T_94f3d_row5_col5 {
#   color: green;
# }
# #T_94f3d_row0_col3, #T_94f3d_row0_col4, #T_94f3d_row0_col5, #T_94f3d_row1_col4, #T_94f3d_row1_col5, #T_94f3d_row2_col5, #T_94f3d_row3_col0, #T_94f3d_row4_col0, #T_94f3d_row4_col1, #T_94f3d_row5_col0, #T_94f3d_row5_col1, #T_94f3d_row5_col2 {
#   color: black;
# }
# </style>
# <table id="T_94f3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
print("Summer Soil Moisture Correlation = ")
sum_sm_corr = sum_sm.corr()
sum_sm_corr.style.applymap(color_positive_green)
# Out:
# Summer Soil Moisture Correlation =
# <style type="text/css">
# #T_a3a5f_row0_col0, #T_a3a5f_row0_col1, #T_a3a5f_row0_col2, #T_a3a5f_row0_col3, #T_a3a5f_row0_col4, #T_a3a5f_row0_col5, #T_a3a5f_row1_col0, #T_a3a5f_row1_col1, #T_a3a5f_row1_col2, #T_a3a5f_row1_col3, #T_a3a5f_row1_col4, #T_a3a5f_row1_col5, #T_a3a5f_row2_col0, #T_a3a5f_row2_col1, #T_a3a5f_row2_col2, #T_a3a5f_row2_col3, #T_a3a5f_row2_col4, #T_a3a5f_row2_col5, #T_a3a5f_row3_col0, #T_a3a5f_row3_col1, #T_a3a5f_row3_col2, #T_a3a5f_row3_col3, #T_a3a5f_row3_col4, #T_a3a5f_row3_col5, #T_a3a5f_row4_col0, #T_a3a5f_row4_col1, #T_a3a5f_row4_col2, #T_a3a5f_row4_col3, #T_a3a5f_row4_col4, #T_a3a5f_row4_col5, #T_a3a5f_row5_col0, #T_a3a5f_row5_col1, #T_a3a5f_row5_col2, #T_a3a5f_row5_col3, #T_a3a5f_row5_col4, #T_a3a5f_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_a3a5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3a5f_level0_col0" class="col_heading level0 col0" >(2015,)</th>
# ...

# %%
print("Fall Soil Moisture Correlation = ")
fall_sm_corr = fall_sm.corr()
fall_sm_corr.style.applymap(color_positive_green)
# Out:
# Fall Soil Moisture Correlation =
# <style type="text/css">
# #T_f2ef4_row0_col0, #T_f2ef4_row1_col1, #T_f2ef4_row2_col2, #T_f2ef4_row3_col3, #T_f2ef4_row4_col4, #T_f2ef4_row4_col5, #T_f2ef4_row5_col4, #T_f2ef4_row5_col5 {
#   color: green;
# }
# #T_f2ef4_row0_col1, #T_f2ef4_row0_col2, #T_f2ef4_row0_col3, #T_f2ef4_row0_col4, #T_f2ef4_row0_col5, #T_f2ef4_row1_col0, #T_f2ef4_row1_col2, #T_f2ef4_row1_col3, #T_f2ef4_row1_col4, #T_f2ef4_row1_col5, #T_f2ef4_row2_col0, #T_f2ef4_row2_col1, #T_f2ef4_row2_col3, #T_f2ef4_row2_col4, #T_f2ef4_row2_col5, #T_f2ef4_row3_col0, #T_f2ef4_row3_col1, #T_f2ef4_row3_col2, #T_f2ef4_row3_col4, #T_f2ef4_row3_col5, #T_f2ef4_row4_col0, #T_f2ef4_row4_col1, #T_f2ef4_row4_col2, #T_f2ef4_row4_col3, #T_f2ef4_row5_col0, #T_f2ef4_row5_col1, #T_f2ef4_row5_col2, #T_f2ef4_row5_col3 {
#   color: black;
# }
# </style>
# <table id="T_f2ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
print("Winter Soil Moisture Correlation = ")
win_sm_corr = win_sm.corr()
win_sm_corr.style.applymap(color_positive_green)
# Out:
# Winter Soil Moisture Correlation =
# <style type="text/css">
# #T_d8dc5_row0_col0, #T_d8dc5_row0_col1, #T_d8dc5_row0_col2, #T_d8dc5_row0_col3, #T_d8dc5_row0_col4, #T_d8dc5_row0_col5, #T_d8dc5_row1_col0, #T_d8dc5_row1_col1, #T_d8dc5_row1_col2, #T_d8dc5_row1_col3, #T_d8dc5_row1_col4, #T_d8dc5_row1_col5, #T_d8dc5_row2_col0, #T_d8dc5_row2_col1, #T_d8dc5_row2_col2, #T_d8dc5_row2_col3, #T_d8dc5_row2_col4, #T_d8dc5_row2_col5, #T_d8dc5_row3_col0, #T_d8dc5_row3_col1, #T_d8dc5_row3_col2, #T_d8dc5_row3_col3, #T_d8dc5_row3_col4, #T_d8dc5_row3_col5, #T_d8dc5_row4_col0, #T_d8dc5_row4_col1, #T_d8dc5_row4_col2, #T_d8dc5_row4_col3, #T_d8dc5_row4_col4, #T_d8dc5_row4_col5, #T_d8dc5_row5_col0, #T_d8dc5_row5_col1, #T_d8dc5_row5_col2, #T_d8dc5_row5_col3, #T_d8dc5_row5_col4, #T_d8dc5_row5_col5 {
#   color: green;
# }
# </style>
# <table id="T_d8dc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8dc5_level0_col0" class="col_heading level0 col0" >(2015,)</th>
# ...

# %% [markdown]
# # Conclusion:

# %% [markdown]
# For sea surface temperature and soil moisture , the summer months and years show the most correlation with each other. Spring also shows high correlations in both value of correlations and the number of years which show correlations. The fall months are uncorrelated for the Sea Surface Temperature and Soil Moisture.
#
# It would be helpful to further investigate the months with the highest correlations.
#
# For future work, it would be helpful to repeat the project for a larger time span, potentially starting at 1979. I was limited in this project by how much processing time I had since the conversion from the Gaussian to Lat/Lon was a very long process.
